# %% [markdown]
# <a href="https://colab.research.google.com/github/jeeva7-student/DatavAnalytics-Using-Python-Project-/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("wellcome",name)
greet("student")
# Out:
# wellcome student

# %%
def greet():
  print("Hello")
greet()
# Out:
# Hello

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30
